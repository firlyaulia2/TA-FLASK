# %%
from PIL import Image
import os

# Path to the folder containing the images
folder_path = '/Users/fadhilahmad/Documents/apl deteksi sayur/model/images'

# Desired dimensions
target_size = (224, 224)

# Function to resize images
def resize_images(folder_path, target_size):
    # Loop through all files in the folder
    for filename in os.listdir(folder_path):
        # Check if the file is an image
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
            # Open the image file
            image_path = os.path.join(folder_path, filename)
            img = Image.open(image_path)
            # Resize the image
            img_resized = img.resize(target_size, Image.LANCZOS)  # You can use other resampling filters like Image.LANCZOS
            # Save the resized image, overwriting the original
            img_resized.save(image_path)
            print(f"Resized {filename} to {target_size}")

# Call the function to resize images
resize_images(folder_path, target_size)
# Out:
# Resized 63.jpg to (224, 224)
# Resized 5109.jpg to (224, 224)
# Resized 2100.jpg to (224, 224)
# Resized 189.jpg to (224, 224)
# Resized 4203.jpg to (224, 224)
# Resized 837.jpg to (224, 224)
# Resized 1353.jpg to (224, 224)
# Resized 3222.jpg to (224, 224)
# Resized 1347.jpg to (224, 224)
# Resized 5121.jpg to (224, 224)
# Resized 5874.jpg to (224, 224)
# Resized 2841.jpg to (224, 224)
# Resized 162.jpg to (224, 224)
# Resized 4773.jpg to (224, 224)
# Resized 1179.jpg to (224, 224)
# Resized 4767.jpg to (224, 224)
# Resized 2316.jpg to (224, 224)
# Resized 5451.jpg to (224, 224)
# Resized 5337.jpg to (224, 224)
# Resized 4029.jpg to (224, 224)
# Resized 1623.jpg to (224, 224)
# Resized 4983.jpg to (224, 224)
# Resized 5445.jpg to (224, 224)
# Resized 4968.jpg to (224, 224)
# Resized 3975.jpg to (224, 224)
# Resized 348.jpg to (224, 224)
# Resized 360.jpg to (224, 224)
# Resized 3168.jpg to (224, 224)
# Resized 4161.jpg to (224, 224)
# Resized 2262.jpg to (224, 224)
# ...
